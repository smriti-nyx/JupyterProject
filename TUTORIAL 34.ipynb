# %% [markdown]
# PYTHON EVAL FUNCTION - EVALUATING EXPRESSIONS DYNAMICALLY

# %%
#eval is considered insecure but those security issues can be overcoem.

# %%
#format = eval(" _ " , globals , locals )

# %%
eval("5+5")
# Out:
# 10

# %%
eval(input("Enter the eval expression: "))
# Out:
# 14

# %%
eval(input("Enter the eval expression: "))
# Out:
# 5

# %%
def square_num(num):
    return num **2

# %%
eval("square_num(4)")
# Out:
# 16

# %% [markdown]
# How does eval work ?
# 1. pass python expression
# 2. compile into a byte code
# 3. evaluate the python expression
# 4. it will return the result.

# %%
var = compile("5+5" , "<string>")
#in eval , the op is passed as a string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 var = compile("5+5" , "<string>")
#       2 #in eval , the op is passed as a string
#
# TypeError: compile() missing required argument 'mode' (pos 3)

# %%
eval(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 eval(var)
#       2
#
# NameError: name 'var' is not defined

# %%
eval("x+20*x" ,{"x" :10})
# Out:
# 210

# %%
x = 90
eval("x**3" , {"x": x})
# Out:
# 729000

# %%
x =29
y = 58
eval("x+y")
# Out:
# 87

# %% [markdown]
# #locals overwrite gloabls

# %%
eval("a+b+c", {} , { "a": 100 ,"b" : 3, "c": 392})
# Out:
# 495

# %%
a = 84
b = 48
eval("a>b")
# Out:
# True
