# %% [markdown]
# STATIC METHODS IN PYTHON

# %%
import datetime
now = datetime.datetime.now()

# %%
now.year
# Out:
# 2026

# %%
class Car:
    base_price  = 100000
    #initialising constructors
    def __init__(self , windows ,doors,power):
        self.windows = windows
        self.doors= doors
        self.power = power


        #fucntion
    def what_base_price(self):
     print("The base price of the car is {}. ".format(self.base_price))

    @classmethod
    def revise_base_price(cls , inflation):
            cls.base_price = cls.base_price + cls.base_price*inflation

    @staticmethod #it gets initialised at first, before anything.
    def check_year():
        if now.year == 2026:
            return True
        else:
            return False

# %%
Car.check_year()
# Out:
# True

# %%
car1 = Car( 3, 4 , 5000)

# %%
car1.check_year()
# Out:
# True

# %%
if(car1.check_year()):
    pass
else:
    Car.revise_base_price()

# %%
car1.base_price
# Out:
# 100000
