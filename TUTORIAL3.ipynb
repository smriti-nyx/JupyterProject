# %% [markdown]
# TUTORIAL 3

# %%
#defining an empty set

# %%
names = {"kristen" , "kat", "karen" , "sophia"}
dates = set()
print(type(names))
print(type(dates))
# Out:
# <class 'set'>
# <class 'set'>

# %%
#inbuilt functions in set
#a set doesnt have duplicate elements

# %%
names1 = { "kat", "krissy","jamie" , "lara", "lara"}
print(names1)
# Out:
# {'kat', 'lara', 'jamie', 'krissy'}

# %%
###indexing in sets is not allowed.

# %%
names2 = {"jelly", "sally", "snowy", "swlly"}
names2.add("kelly")
print(names2)
# Out:
# {'kelly', 'jelly', 'swlly', 'sally', 'snowy'}

# %%
#intersection and intersection updat e

# %%
#difference and difference update

names3 = {"guava", "apple", "orange", "pear"}
names4 = { "orange", "apple", "pear" ,"guava", "coconut"}
names4.difference_update(names3)
print(names4)
# Out:
# {'coconut'}

# %%
print(names4)
# Out:
# {'guava', 'coconut', 'orange', 'pear', 'apple'}

# %%
#DICTIONARIES
