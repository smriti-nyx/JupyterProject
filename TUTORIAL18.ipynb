# %% [markdown]
# STRING FORMATION

# %% [raw]
# #string formation

# %%
def greeting(name ,age):
    return "Hello {}. Your age is {} ." .format(name , age )

# %%
greeting("Sera", 20)
# Out:
# 'Hello Sera. Your age is 20 .'
