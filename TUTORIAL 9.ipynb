# %% [markdown]
#  -TUTORIAL 9

# %% [raw]
# #Seaborn Tutorial
# #visual data representation tool/library
# ##types
# #displot (for creating a histogram)
# #joinplot (for one independent parameter)
# #pairplot or scatterplot (for more thsan one independent parameter)
# #practice problem on IRIS dataset

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import Series, DataFrame

# %%
import os

[f for f in os.listdir() if f.lower().endswith(".csv")]
# Out:
# ['test.csv']

# %%
import seaborn as sns
import certifi
import pandas as pd
import ssl
import certifi
from urllib.request import urlopen
ssl_context = ssl.create_default_context(cafile=certifi.where())

ssl_context = ssl.create_default_context(cafile=certifi.where())

# %%
df = sns.load_dataset('tips.csv')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
#Correlation with heatmap

# %%
#uses colored cell , typically in a monochromatic scale to show a 2D corrrelation matrix between two discretedimennsions or event types.

# %%
import os
os.listdir()
# Out:
# ['TUTORIAL [4:].ipynb',
#  'requirements.txt',
#  'test png.png',
#  'test.csv',
#  'models',
#  'README.md',
#  'sample.ipynb',
#  '.venv',
#  'TUTORIAL7.ipynb',
#  'TUTORIAL 9.ipynb',
#  '.git',
#  'data',
#  'TUTORIAL6.ipynb',
#  'TUTORIAL 8.ipynb',
#  'TUTORIAL6789.ipynb',
#  '.idea']

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import seaborn as sns

df = sns.load_dataset("tips")
df.head()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
import os
os.getcwd()
# Out:
# '/Users/smritimishra/PycharmProjects/JupyterProject'

# %%
os.listdir()
# Out:
# ['TUTORIAL [4:].ipynb',
#  'requirements.txt',
#  'test png.png',
#  'test.csv',
#  'models',
#  'README.md',
#  'sample.ipynb',
#  '.venv',
#  'TUTORIAL7.ipynb',
#  'TUTORIAL 9.ipynb',
#  '.git',
#  'data',
#  'TUTORIAL6.ipynb',
#  'TUTORIAL 8.ipynb',
#  'TUTORIAL6789.ipynb',
#  '.idea']

# %%
import os

for root, dirs, files in os.walk(os.path.expanduser("~")):
    if "tips.csv" in files:
        print(os.path.join(root, "tips.csv"))
# Out:
# /Users/smritimishra/Downloads/tips.csv

# %%
df = pd.read_csv("/Users/smritimishra/Downloads/tips.csv")

# %%
sns.scatterplot(data=df, x="total_bill", y="tip")
plt.show()

# %%
import os
os.listdir()
# Out:
# ['TUTORIAL [4:].ipynb',
#  'requirements.txt',
#  'test png.png',
#  'test.csv',
#  'tips.csv',
#  'models',
#  'README.md',
#  'sample.ipynb',
#  '.venv',
#  'TUTORIAL7.ipynb',
#  'TUTORIAL 9.ipynb',
#  '.git',
#  'data',
#  'TUTORIAL6.ipynb',
#  'TUTORIAL 8.ipynb',
#  'TUTORIAL6789.ipynb',
#  '.idea']

# %%
df = sns.load_dataset('tips.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# ...
