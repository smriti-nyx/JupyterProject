# %% [markdown]
# TUTORIAL 5

# %%
import numpy as np
import pandas as pd

# %%
#playing with data frame
df= pd.DataFrame(np.arange(0,20).reshape(5,4), index = ["Row1", "Row2", "Row3", "Row4", "Row5"] , columns = ["Column1", "Column2", "Column3", "Column4"])
df.head()
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
#file saved with comma separation = CSV comma separated value
df.to_csv('TEST1.csv')

# %%
#Accessing the elements
## there are 2 ways to do that
### 1. .loc , 2. .iloc (loc as in location and i is for index
#if no row & column both >1 its a data frame but if even a row or column =1
#it is DATA SERIES & not DATA FRAME .

# %%
df.loc["Row1"]
# Out:
# Column1    0
# Column2    1
# Column3    2
# Column4    3
# Name: Row1, dtype: int64

# %%
type(df.loc["Row1"]) #output says that it is a series since only one row has been chosen
# Out:
# pandas.core.series.Series

# %%
df.iloc[0:2 , 1:3]
# Out:
#       Column2  Column3
# Row1        1        2
# Row2        5        6

# %%
df.iloc[0:3 , 2:4]
# Out:
#       Column3  Column4
# Row1        2        3
# Row2        6        7
# Row3       10       11

# %%
df["Column1"].unique()
# Out:
# array([ 0,  4,  8, 12, 16])

# %%
df.iloc[0:3 , 2:4].values.shape
# Out:
# (3, 2)

# %%
df.isnull().sum() #means column 1 has 0 null values
#first thing you check in any data set
# Out:
# Column1    0
# Column2    0
# Column3    0
# Column4    0
# dtype: int64

# %%
df["Column1"].value_counts()
# Out:
# Column1
# 0     1
# 4     1
# 8     1
# 12    1
# 16    1
# Name: count, dtype: int64

# %%
`df[["Column1", "Column2"]] #calling the columns
# Out:
#   Cell In[17], line 1
#     `df[["Column1", "Column2"]] #calling the columns
#     ^
# SyntaxError: invalid syntax
