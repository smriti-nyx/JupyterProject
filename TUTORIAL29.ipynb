# %% [markdown]
# PYTHON  IS - KEYWORD

# %%
# == : it asks if a is equal to b , stored at diff memory locations
## is : the two items in question hsould also be locaated at the same memory location

# %%
lst1 = [1,2,3]
lst2= [1,2,3]
lst1 == lst2
# Out:
# True

# %%
lst1 is lst2
# Out:
# False

# %%
#fix
lst1 = [1,2,3]
lst2 = lst1
lst1 is lst2
# Out:
# True
