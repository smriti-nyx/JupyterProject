# %% [markdown]
# CLASS METHODS AND CLASS VARIABLES

# %%
class Car:
    base_price  = 100000
    #initialising constructors
    def __init__(self , windows ,doors,power):
        self.windows = windows
        self.doors= doors
        self.power = power
        #fucntion
        def what_base_price(self):
            print("The base price of the car is {}. ".format(self.base_price))

# %%
#ways to access the base price
car1 = Car(2,4,2000)
car1.base_price
# Out:
# 100000

# %%
Car.base_price
# Out:
# 100000

# %%
#the task : we want to record the base  prices everywhere due to inflation . we create a function which increases the base price aq to inflation and gives us revised base price

# %%
class Car:
    base_price  = 100000
    #initialising constructors
    def __init__(self , windows ,doors,power):
        self.windows = windows
        self.doors= doors
        self.power = power


        #fucntion
    def what_base_price(self):
     print("The base price of the car is {}. ".format(self.base_price))

    @classmethod
    def revise_base_price(cls , inflation):
            cls.base_price = cls.base_price + cls.base_price*inflation

# %%
#calculation of revised base prices

# %%
Car.base_price
# Out:
# 100000

# %%
Car.revise_base_price(0.10)

# %%
car1 = Car(3,4,2000)
car1.base_price
# Out:
# 110000.0

# %%
car1.revise_base_price(0.10)
car1.base_price
# Out:
# 121000.0

# %%
car1.revise_base_price(0.10)
car1.base_price
# Out:
# 146410.0

# %%
#but the method to call this fnc is
Car.revise_base_price(0.6)

# %%
Car.base_price
# Out:
# 234256.0
